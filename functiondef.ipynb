# %%
#Function
#It is block of organized, re-usable code that is used to perform single operation.

# %%
# defining a function

#def add()

Syntax of a function:
    def functionname(parameters):
        "function_docstring"
         logic of the need
            return(expression)
    1. defining a function : -----> Parameters Passing(define)
    2. function calling : --------> arguments passing(calling)

# %%
def functiontest(mylist):
    "This is tets function to update list"
    mylist.append([4,5,6])
    print("I'm calling from inside the function",mylist)
    
mylist=[1,2,3]
functiontest(mylist)
print("I'm calling from outside the function",mylist)
# Out:
# I'm calling from inside the function [1, 2, 3, [4, 5, 6]]
# I'm calling from outside the function [1, 2, 3, [4, 5, 6]]
