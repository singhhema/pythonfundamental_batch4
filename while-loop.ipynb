# %%
# while loop

i=1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Generators - way of implementing iteration is called generators
i=1
while i<=5:
    print(i)
    i+=1
else:
        print("i is no longer less than 5")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 5

# %%
#Functions
# block of code which runs only when  it is called
def my_function():
    print("Hello, this is my code")
my_function()
# Out:
# Hello, this is my code

# %%
def name(i):
    print(str(i) + 'hema')
name(5)
print(type(name))
# Out:
# 5hema
# <class 'function'>
