# %%
#changing, removing and inserting elements in a list.

# %%
#change element in a list

laptop=['lenovo','dell','hp']
print(laptop)
# Out:
# ['lenovo', 'dell', 'hp']

# %%
laptop[2]='samsung'
print(laptop)
# Out:
# ['lenovo', 'dell', 'samsung']

# %%
#insert element in a list
laptop
# Out:
# ['lenovo', 'dell', 'samsung']

# %%
laptop.append='sony'
laptop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-367b8d483e9b> in <module>
# ----> 1 laptop.append='sony'
#       2 laptop
#
# AttributeError: 'list' object attribute 'append' is read-only

# %%
laptop.append('sony')
laptop
# Out:
# ['lenovo', 'dell', 'samsung', 'sony']

# %%
#add element at specific index postion
laptop.insert(2,'apple')
laptop
# Out:
# ['lenovo', 'dell', 'apple', 'samsung', 'sony']

# %%
#removing element in a list

# %%
del laptop[1]
laptop
# Out:
# ['lenovo', 'apple', 'samsung', 'sony']

# %%
popped_laptop=laptop.pop()
print(popped_laptop)
print(laptop)
# Out:
# samsung
# ['lenovo', 'apple']

# %%
popped_laptop=laptop.pop(0)
print(popped_laptop)
print(laptop)
# Out:
# lenovo
# ['apple']
