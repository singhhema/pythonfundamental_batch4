# %%
a=['hema','abhi','karan','ravi']
print(a)
# Out:
# ['hema', 'abhi', 'karan', 'ravi']

# %%
a.pop(0)
# Out:
# 'hema'

# %%
print(a)
# Out:
# ['abhi', 'karan', 'ravi']

# %%
birds=['parrot','sparrow','eagle','crow']
print(birds)
# Out:
# ['parrot', 'sparrow', 'eagle', 'crow']

# %%
birds.remove(crow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9bb111638da4> in <module>
# ----> 1 birds.remove(crow)
#
# NameError: name 'crow' is not defined

# %%
birds.remove('crow')

# %%
birds
# Out:
# ['parrot', 'sparrow', 'eagle']

# %%
animals=['cow','lion','tiger','monkey']
animals.sort()
animals
# Out:
# ['cow', 'lion', 'monkey', 'tiger']

# %%
books=['chemistry','physics','biology','maths','English']
print(books)
# Out:
# ['chemistry', 'physics', 'biology', 'maths', 'English']

# %%
sorted.books()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8ac188da0d34> in <module>
# ----> 1 sorted.books()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'books'

# %%
sorted(books)
# Out:
# ['English', 'biology', 'chemistry', 'maths', 'physics']

# %%
print(books)
# Out:
# ['chemistry', 'physics', 'biology', 'maths', 'English']

# %%
books=['Chemistry', 'physics', 'biology', 'Maths', 'English']
sorted(books)
# Out:
# ['Chemistry', 'English', 'Maths', 'biology', 'physics']

# %%
books.reverse()

# %%
print(books)
# Out:
# ['English', 'Maths', 'biology', 'physics', 'Chemistry']
