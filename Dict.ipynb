# %%
#DICTIONARY
#key-value pair declaration :
#want to create a facebook account:
#username : abhi25 ......key
#password : XXXXXXXx......value .......-->account gets unlocked or accessible
#passworderror : try again

# %%
#to declare a dictionary we can use {}(flower bracket)
list-[]
tuple-()
dict-{}
string- ''

# %%
x={'Name':'Hema','Age':8,'class':7}
print(x)
# Out:
# {'Name': 'Hema', 'Age': 8, 'class': 7}

# %%
#how to access values in a dictionary:
print(x['Name'])
# Out:
# Hema

# %%
print(x['class'])
# Out:
# 7

# %%
#if we are trying to access data which is not present in the above dict
print(x['surname'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ea74417bdcfe> in <module>
#       1 #if we are trying to access data which is not present in the above dict
# ----> 2 print(x['surname'])
#
# KeyError: 'surname'

# %%
#dictionary is a mutable data type
x={'Name':'Hema','age':8,'class':4}
x['age']=9  #update valut in dictionary
x['school']='DPS' # added a new key=-pair value
print(x)
# Out:
# {'Name': 'Hema', 'age': 9, 'class': 4, 'school': 'DPS'}

# %%
#how to delete values from dictionary
del x['class']

# %%
print(x)
# Out:
# {'Name': 'Hema', 'age': 9, 'class': 4, 'school': 'DPS'}

# %%
x.clear()
print(x)
# Out:
# {}

# %%
del x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8c23cd95a3fd> in <module>
#       1 del x
# ----> 2 print(x)
#
# NameError: name 'x' is not defined
