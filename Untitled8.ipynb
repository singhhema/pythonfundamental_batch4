# %%
x=int(input("Enter your Age"))
if x>=18:
    print("You're eligible")
else:
    print("You are not eligible")
# Out:
# Enter your Age56
# You're eligible

# %%
request_toppings = ['mushrooms','onions','origano']
'tomato'in request_toppings
# Out:
# False

# %%
request_toppings = ['mushrooms','onions','origano']
'mushrooms'in request_toppings
# Out:
# True

# %%
banned_user=['anil','smith','anjali','ajay']
user=str(input("Enter your name"))
if user not in banned_user:
    print(f"{user.title()}, you can text him")
else:
    print(f"{user.title()}, is banned")
# Out:
# Enter your nameanil
# Anil, is banned

# %%
unlock_code = 12345
if unlock_code == 12345:
    print("phone gets unlocked")
else:
    print("invalid password,try again")
# Out:
# phone gets unlocked
