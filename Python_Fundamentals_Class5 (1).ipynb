# %%
favourite_lang="python"
print(favourite_lang)
# Out:
# python

# %%
favourite_lang='python '


favourite_lang.rstrip()
# Out:
# 'python'

# %%
favourite_lang=' python'


favourite_lang.rstrip()
# Out:
# ' python'

# %%
favourite_lang=' python'


favourite_lang.lstrip()
# Out:
# 'python'

# %%
favourite_lang='python'


favourite_lang.strip()
# Out:
# 'python'

# %%
x='python is highly popular language'
print(x)
# Out:
# python is highly popular language

# %%
x='python is highly popular language & it's an open source programming language'
print(x)
# Out:
#   File "<ipython-input-9-58da0d97a434>", line 1
#     x='python is highly popular language & it's an open source programming language'
#                                               ^
# SyntaxError: invalid syntax

# %%
x="python is highly popular language & it's an open source programming language"
print(x)
# Out:
# python is highly popular language & it's an open source programming language

# %%
2+3
# Out:
# 5

# %%
4/5
# Out:
# 0.8

# %%
7.0*3
# Out:
# 21.0

# %%
5*6
# Out:
# 30

# %%
5**4
# Out:
# 625

# %%
7**3
# Out:
# 343

# %%
customer_salary=140 000 000 000
print(customer_salary)
# Out:
#   File "<ipython-input-17-79efb66a3d69>", line 1
#     customer_salary=140 000 000 000
#                           ^
# SyntaxError: invalid syntax

# %%
customer_salary=140_000_000_000
print(customer_salary)
# Out:
# 140000000000
